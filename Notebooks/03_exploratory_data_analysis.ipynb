# %%
# %run
./02_data_cleaning_pandas

# %%
import matplotlib.pyplot as plt

# Sales by Category
category_sales = df.groupby("Category")["TotalSales"].sum()

category_sales.plot(kind="bar", title="Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# Daily Sales Trend
daily_sales = df.groupby("Date")["TotalSales"].sum().sort_index()

daily_sales.plot(title="Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.show()
